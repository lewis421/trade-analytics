# %%
# Define the ticker symbol for Apple
import yfinance as yf
ticker_symbol = 'AAPL'

# Define the start and end dates for the data
start_date = '2020-01-01'  # Example start date
end_date = '2025-01-01'  # Example end date (Note: the current date is August 16, 2025, so adjust the end date for more recent data if desired)

# Download the data
df = yf.download(ticker_symbol, start=start_date, end=end_date)
df.to_csv("apple_daily_ohlcv.csv")
# Out:
# /var/folders/lz/74xdvqqn67113h8lw4mnp0_00000gn/T/ipykernel_16615/750166947.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.538513   72.598892   71.292304   71.545890  135480400
# 2020-01-03   71.833298   72.594063   71.608692   71.765674  146322800
# 2020-01-06   72.405670   72.444313   70.703005   70.954181  118387200
# 2020-01-07   72.065140   72.671333   71.845362   72.415330  108872000
# 2020-01-08   73.224411   73.526303   71.768086   71.768086  132079200
# ...                ...         ...         ...         ...        ...
# 2024-12-24  257.286682  257.296626  254.386957  254.586262   23234700
# 2024-12-26  258.103729  259.179926  256.718662  257.276679   27237100
# 2024-12-27  254.685867  257.784882  252.164818  256.917934   42355300
# 2024-12-30  251.307877  252.603281  249.863009  251.337769   35557500
# 2024-12-31  249.534180  252.384064  248.547676  251.547039   39480700
#
# [1258 rows x 5 columns]
